# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Reading in data
march2020 = pd.read_csv('./march2020.csv')
may2020 = pd.read_csv('./may2020.csv')
july2020 = pd.read_csv('./july2020.csv')

# Removing commas and converting to float for all of the string elements
def parse(df, col):
    clean = []
    for elem in df[col].values:
        elem = elem.replace(',', '')
        clean.append(float(elem))
        
    df[col] = clean
    
colList = ['totalSoybeanMealSupply', 'totalSoybeanMealDemand', 'soybeanOilSupply', 'soybeanOilDemand']

def parseAllCol(df, listOfCol):
    for col in listOfCol:
        parse(df, col)
        
parseAllCol(march2020, colList)

parseAllCol(may2020, colList)

parseAllCol(july2020, colList)


march2020.head()
# Out:
#          date  openPrice  highPrice  lowPrice  closePrice  \
# 0  11/14/2017      978.5      978.5     978.5       978.5
# 1  11/15/2017      985.0      985.0     985.0       985.0
# 2  11/16/2017      983.0      983.0     983.0       983.0
# 3  11/17/2017      996.5      996.5     996.5       996.5
# 4  11/20/2017      998.5      998.5     998.5       998.5
#
#    totalSoybeanMealSupply  totalSoybeanMealDemand  soybeanOilSupply  \
# 0                  4526.6                  4137.5            3625.3
# 1                  4526.6                  4137.5            3625.3
# 2                  4526.6                  4137.5            3625.3
# 3                  4526.6                  4137.5            3625.3
# 4                  4526.6                  4137.5            3625.3
#
#    soybeanOilDemand  sunflowerSeedPrice  ... soybeanOilPrice  \
# 0            1934.7                16.6  ...           33.43
# 1            1934.7                16.6  ...           33.43
# 2            1934.7                16.6  ...           33.43
# 3            1934.7                16.6  ...           33.43
# 4            1934.7                16.6  ...           33.43
#
#    cottonseedOilPrice  sunflowerseedOilPrice  canolaOilPrice  peanutOilPrice  \
# 0                37.0                   55.5           39.69            65.0
# 1                37.0                   55.5           39.69            65.0
# 2                37.0                   55.5           39.69            65.0
# 3                37.0                   55.5           39.69            65.0
# 4                37.0                   55.5           39.69            65.0
#
#    cornOilPrice  soybeanMealPrice  cottonseedmealPrice  \
# 0         34.46            313.52               228.75
# 1         34.46            313.52               228.75
# 2         34.46            313.52               228.75
# 3         34.46            313.52               228.75
# 4         34.46            313.52               228.75
#
#    sunflowerseedMealPrice  linseedMealPrice
# 0                   165.0             205.0
# 1                   165.0             205.0
# 2                   165.0             205.0
# 3                   165.0             205.0
# 4                   165.0             205.0
#
# [5 rows x 24 columns]

# %%
corrMarch = march2020.corr()
mar = sns.heatmap(corrMarch, vmax = 1.0, square = True)
mar.set_title('March 2020 Contract Date Feature and Label Correlation')
# Out:
# Text(0.5, 1.0, 'March 2020 Contract Date Feature and Label Correlation')

# %%
corrMay = may2020.corr()
may = sns.heatmap(corrMay, vmax = 1.0, square = True)
may.set_title('May 2020 Contract  Date Feature and Label Correlation')
# Out:
# Text(0.5, 1.0, 'May 2020 Contract  Date Feature and Label Correlation')

# %%
corrJuly = july2020.corr()
jul = sns.heatmap(corrJuly, vmax = 1.0, square = True)
jul.set_title('July 2020 Contract Date Feature and Label Correlation')
# Out:
# Text(0.5, 1.0, 'July 2020 Contract Date Feature and Label Correlation')

# %%
# Writing to csv
corrMarch.to_csv('./corrMarch.csv')
corrMay.to_csv('./corrMay.csv')
corrJuly.to_csv('./corrJuly.csv')
